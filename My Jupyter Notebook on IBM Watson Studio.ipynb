# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mustafa Albahrani**
#
# Network Operations Engineer

# %% [markdown]
# _I am interested in Data Science because I like to understand the hidden information about business._

# %% [markdown]
# ### The following code print Hi

# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# objects | count | price
# --- | --- | ---
# Table | 3 | 100

# %% [markdown]
# 1. one
# 2. two
# 3. three
# * apple
# * orange

# %% [markdown]
# https://www.google.com/
